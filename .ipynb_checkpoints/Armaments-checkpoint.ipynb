# %% [markdown]
# # Armaments Applied to Other Mod Armies
# v0.4.1
# I was too lazy to spend two hours hand modifying all the armies from other mods in which someone else had not already added. So I spent thrice as many hours scripting this which should be able to handle anyone's modded armies and add reasonable armament costs and upkeeps to them. Or soon will at least.
#
# This pipeline is designed around the use of Irony Mod Manager making a snap shots of the mods and merging them together. The target folder for input should be where your ironymodmanager's mod in questions's army folder is. It will then edit the same files. This piple (will) take into account duplicates from patch files.

# %% [markdown]
# ## Table of Contents
#
# - [Parsing Stellaris Army Files](#parsing-stellaris-army-files)
# - [Initial Reading & Basic Cleaning](#initial-reading--basic-cleaning)
# - [Damping Logic](#damping-logic)
# - [Designer Table Scripting](#designer-table-scripting)
# - [Common Functions](#common-functions)
# - [Main Modeling & Prediction](#main-modeling--prediction)

# %%
import os
import re
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from IPython.display import HTML, display

# %% [markdown]
# ## Parsing Stellaris Army Files
# <a id="parsing-stellaris-army-files"></a>

# %%
def parse_army_files(input_directory):
    """
    Parse text files containing Stellaris army definitions.
    """
    army_data = []
    level_1_attributes = set()
    level_2_attributes = set()

    
    def parse_block(block, depth):
        data = {}
        lines = block.splitlines()
        i = 0
        while i < len(lines):
            line = lines[i].strip()
            if line.startswith("#"):
                i += 1
                continue
            if "=" in line and not line.endswith("{"):
                key, value = map(str.strip, line.split("=", 1))
                key = key.rstrip("=").strip()
                data[key] = value
                if depth == 1:
                    level_1_attributes.add(key)
            elif line.endswith("{"):
                key = line[:-1].strip().rstrip("=").strip()
                if depth == 1:
                    level_1_attributes.add(key)
                nested_block = []
                open_braces = 1
                i += 1
                while i < len(lines) and open_braces > 0:
                    nested_line = lines[i].strip()
                    if "{" in nested_line:
                        open_braces += 1
                    if "}" in nested_line:
                        open_braces -= 1
                    nested_block.append(nested_line)
                    i += 1
                nested_data = parse_block("\n".join(nested_block[:-1]), depth + 1)
                if key == "resources":
                    for sub_key in nested_data.keys():
                        level_2_attributes.add(sub_key)
                data[key] = nested_data
                continue
            i += 1
        return data

    for file_name in os.listdir(input_directory):
        if file_name.endswith(".txt"):
            with open(os.path.join(input_directory, file_name), "r", encoding="utf-8") as f:
                content = f.read()
            matches = re.finditer(r"^([a-zA-Z0-9_]+)\s*=\s*\{", content, re.MULTILINE)
            for match in matches:
                army_name = match.group(1).strip()
                start_pos = match.end()
                open_braces = 1
                end_pos = start_pos
                while open_braces > 0 and end_pos < len(content):
                    if content[end_pos] == "{":
                        open_braces += 1
                    elif content[end_pos] == "}":
                        open_braces -= 1
                    end_pos += 1
                block_content = content[start_pos:end_pos - 1]
                army_info = parse_block(block_content, 1)
                army_data.append({"name": army_name, **army_info})

    return army_data, level_1_attributes, level_2_attributes

# %% [markdown]
# ## Initial Reading & Basic Cleaning
# <a id="initial-reading--basic-cleaning"></a>

# %%
def get_sub_df(input_directory):
    """
    Create a DataFrame of armies, extracting relevant columns and
    converting cost/upkeep dictionaries into numeric columns.
    """
    army_data, level_1_attributes, level_2_attributes = parse_army_files(input_directory)
    if not army_data:
        raise ValueError("No data was parsed. Check the Stellaris configuration files.")

    all_columns = ["name"] + sorted(list(level_1_attributes)) + sorted(list(level_2_attributes))
    rows = []
    for army in army_data:
        row = {"name": army.get("name", "")}
        for col in level_1_attributes:
            row[col] = army.get(col, "")
        resources = army.get("resources", {})
        for col in level_2_attributes:
            row[col] = resources.get(col, "")
        rows.append(row)

    df = pd.DataFrame(rows, columns=all_columns)

    # Drop extraneous columns
    cols_to_remove = ['resources', 'icon_frame', 'icon', 'occupation', 'use_armynames_from']
    df.drop(columns=[c for c in cols_to_remove if c in df.columns], inplace=True)

    # Keep only essential attributes
    keep = ['name', 'time', 'damage', 'health', 'morale_damage', 'morale', 'collateral_damage', 'cost', 'upkeep', 'defensive', 
        'war_exhaustion']
    
    df = df[keep].copy()

    # Convert the 'cost' and 'upkeep' columns from strings to dicts
    def convert_to_dict(entry):
        if isinstance(entry, str):
            try:
                return ast.literal_eval(entry)
            except (ValueError, SyntaxError):
                return {}
        elif isinstance(entry, float) or entry is None:
            return {}
        return entry

    df['cost'] = df['cost'].apply(convert_to_dict)
    df['upkeep'] = df['upkeep'].apply(convert_to_dict)

    
    # Expand cost & upkeep dicts into numeric columns
    def parse_resources_column(df_local, column):
        resource_keys = set()
        for entry in df_local[column].dropna():
            if isinstance(entry, dict):
                resource_keys.update(entry.keys())
        for key in resource_keys:
            df_local[f"{column}_{key}"] = df_local[column].apply(
                lambda x: float(x[key]) if isinstance(x, dict) and key in x else 0.0
            )
        return df_local

    df = parse_resources_column(df, 'cost')
    df = parse_resources_column(df, 'upkeep')
    df.drop(columns=['cost', 'upkeep'], inplace=True)

    # Identify relevant numeric columns dynamically
    numeric_cols = ['time', 'morale', 'damage', 'health', 'morale_damage', 
                    'collateral_damage', 'war_exhaustion']
    
    # Dynamically include all cost_* and upkeep_* columns
    cost_cols = [col for col in df.columns if col.startswith('cost_')]
    upkeep_cols = [col for col in df.columns if col.startswith('upkeep_')]
    
    # Combine all numeric columns
    all_numeric_cols = numeric_cols + cost_cols + upkeep_cols
    
    # Convert to numeric and handle 'time' as integer
    df[all_numeric_cols] = df[all_numeric_cols].apply(pd.to_numeric, errors='coerce').fillna(0)
    
    # Ensure cost_* columns and 'time' are integers
    df[cost_cols + ['time']] = df[cost_cols + ['time']].astype(int)

    return df

# %% [markdown]
# ## Damping Logic
# <a id="damping-logic"></a>

# %%
dampening_config = {
    'cost_sr_armaments':  {'threshold_factor': 1.1, 'exponent_factor': 0.75},
    'upkeep_sr_armaments': {'threshold_factor': 1.1, 'exponent_factor': 0.015},
}

def apply_dampening(df, armament_df, config):
    """
    Exponential dampening of newly calculated cost/upkeep columns,
    referencing the peak from 'armament_df'. 
    If 'calculated_cost_sr_armaments' or 'calculated_upkeep_sr_armaments'
    does not exist in df, that portion is skipped.
    """
    # Dampening for cost:
    if 'calculated_cost_sr_armaments' in df.columns:
        peak_cost = armament_df['cost_sr_armaments'].max()
        if pd.notnull(peak_cost) and peak_cost > 0:
            cost_settings = config['cost_sr_armaments']
            cost_threshold_value = cost_settings['threshold_factor'] * peak_cost
            cost_exponent_factor = cost_settings['exponent_factor']

            def dampen_cost(x):
                if x <= cost_threshold_value:
                    return x
                diff = x - cost_threshold_value
                return cost_threshold_value + diff / (1 + cost_exponent_factor * diff)

            df['calculated_cost_sr_armaments'] = df['calculated_cost_sr_armaments'].apply(dampen_cost)

    # Dampening for upkeep:
    if 'calculated_upkeep_sr_armaments' in df.columns:
        peak_upkeep = armament_df['upkeep_sr_armaments'].max()
        if pd.notnull(peak_upkeep) and peak_upkeep > 0:
            upkeep_settings = config['upkeep_sr_armaments']
            upkeep_threshold_value = upkeep_settings['threshold_factor'] * peak_upkeep
            upkeep_exponent_factor = upkeep_settings['exponent_factor']

            def dampen_upkeep(x):
                if x <= upkeep_threshold_value:
                    return x
                diff = x - upkeep_threshold_value
                return upkeep_threshold_value + diff / (1 + upkeep_exponent_factor * diff)

            df['calculated_upkeep_sr_armaments'] = df['calculated_upkeep_sr_armaments'].apply(dampen_upkeep)

    return df

# %% [markdown]
# ## Designer Table Scripting
# <a id="designer-table-scripting"></a>

# %%
def reorder_columns(df):
    """
    Reorder DataFrame columns to prioritize key attributes:
    name, time, health, damage, morale, morale_damage, collateral_damage,
    cost_sr_armaments, upkeep_sr_armaments.
    Any remaining columns are appended in alphabetical order.
    """
    
    preferred_cols = ["name", "time", "health", "damage", "morale", "morale_damage", "collateral_damage", "war_exhaustion",
        "cost_sr_armaments", "upkeep_sr_armaments"]
    
    # Identify remaining columns not in preferred_cols
    remaining_cols = [col for col in df.columns if col not in preferred_cols]
    
    # Sort remaining columns by frequency of non-zero values (descending), then alphabetically
    non_zero_counts = df[remaining_cols].astype(bool).sum().sort_values(ascending=False)
    sorted_remaining = sorted(
        remaining_cols,
        key=lambda x: (-non_zero_counts.get(x, 0), x)
    )
    
    # Final column order
    final_cols = [col for col in preferred_cols if col in df.columns] + sorted_remaining
    return df[final_cols]


def display_scrollable_df(df, max_height=800, max_width=1400):
    """
    Reorder columns, apply specific formatting, highlight non-zero cost/upkeep cells
    with different colors, and display the DataFrame in a scrollable HTML container.
    """
    # Reorder columns as specified
    df_ordered = reorder_columns(df)
    
    # Identify cost and upkeep columns for highlighting
    cost_cols = [c for c in df_ordered.columns if "cost" in c.lower()]
    upkeep_cols = [c for c in df_ordered.columns if "upkeep" in c.lower()]

    # Define them here
    def highlight_cost(row):
        highlight_color = "#fffbcc"
        return [
            f"background-color: {highlight_color}"
            if (isinstance(val, (int, float)) and val != 0)
            else ""
            for val in row
        ]

    def highlight_upkeep(row):
        highlight_color = "#ccf2ff"
        return [
            f"background-color: {highlight_color}"
            if (isinstance(val, (int, float)) and val != 0)
            else ""
            for val in row
        ]

    styler = df_ordered.style
    styler = styler.apply(highlight_cost, subset=cost_cols, axis=1)
    
    # Define formatting for specific columns
    formatting_dict = {}
    if 'cost_sr_armaments' in df_ordered.columns:
        formatting_dict['cost_sr_armaments'] = "{:.0f}"  # No decimals
    if 'upkeep_sr_armaments' in df_ordered.columns:
        formatting_dict['upkeep_sr_armaments'] = "{:.1f}"  # One decimal
    if 'morale' in df_ordered.columns:
        formatting_dict['morale'] = "{:.2f}"  # Two decimals
    
    # Apply formatting
    styler = styler.format(formatting_dict)
    
    # Define a function to highlight non-zero cost cells
    def highlight_cost(x):
        return ['background-color: #fffbcc' if (isinstance(v, (int, float)) and v != 0) else '' for v in x]
    
    # Define a function to highlight non-zero upkeep cells
    def highlight_upkeep(x):
        return ['background-color: #ccf2ff' if (isinstance(v, (int, float)) and v != 0) else '' for v in x]
    
    # Apply highlighting to cost columns
    if cost_cols:
        styler = styler.apply(highlight_cost, subset=cost_cols, axis=0)
    
    # Apply highlighting to upkeep columns
    if upkeep_cols:
        styler = styler.apply(highlight_upkeep, subset=upkeep_cols, axis=0)
    
    # Hide the index using Styler's built-in method
    styler = styler.hide(axis="index")
    
    # Render the styled DataFrame to HTML using to_html()
    html_table = styler.to_html()
    
    # Wrap the HTML table in a scrollable container
    scrollable_html = f"""
    <div style='max-height:{max_height}px; max-width:{max_width}px; 
                overflow:auto; border:1px solid #ccc;'>
        {html_table}
    </div>
    """
    display(HTML(scrollable_html))


def scatter_charts(df, attributes, target_col, title_prefix, color, figsize=(12, 6)):
    """
    Generate scatter charts showing the relationship between each attribute 
    and a target column for a single DataFrame.
    """
    num_attributes = len(attributes)
    num_cols = 2  # Display 2 plots per row
    num_rows = (num_attributes + num_cols - 1) // num_cols

    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    axes = axes.flatten()

    for i, attribute in enumerate(attributes):
        ax = axes[i]
        ax.scatter(df[attribute], df[target_col], alpha=0.6, color=color)
        ax.set_title(f"{title_prefix}: vs {attribute}")
        ax.set_xlabel(attribute)
        ax.set_ylabel(target_col.split('_')[-1].capitalize())
        ax.grid(True)

    # Turn off unused subplots
    for i in range(len(attributes), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Common Functions
# <a id="common-functions"></a>

# %%
def fit_pls_model(armies_df, features, target_col, n_components=2):
    """
    Fit a partial least squares regression model.
    """
    if armies_df.empty:
        raise ValueError(f"DataFrame is empty for '{target_col}'.")
    df_local = armies_df.dropna(subset=features + [target_col]).copy()
    if df_local.empty:
        raise ValueError(f"All rows dropped for '{target_col}' after dropna on {features} and target.")
    X = df_local[features].fillna(0).values
    y = df_local[target_col].values
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    pls = PLSRegression(n_components=n_components)
    pls.fit(X_scaled, y)
    return pls, scaler


def predict_pls(armies_df, features, pls_model, scaler):
    """
    Use the PLS model to predict cost/upkeep for armies.
    """
    X = armies_df[features].fillna(0).values
    X_scaled = scaler.transform(X)
    preds = pls_model.predict(X_scaled).ravel()
    return np.clip(preds, a_min=0, a_max=None)


def round_cost_upkeep(df_local, cost_col='cost_sr_armaments', upkeep_col='upkeep_sr_armaments'):
    """
    Round cost to the nearest multiple of 10 and upkeep to the nearest 0.25.
    Eliminate trailing zeros for upkeep.
    If cost_col or upkeep_col is None (or missing), it is skipped.
    """
    if cost_col and (cost_col in df_local.columns):
        df_local[cost_col] = pd.to_numeric(df_local[cost_col], errors='coerce').fillna(0)
        df_local[cost_col] = (np.ceil(df_local[cost_col] / 10) * 10).astype(int)

    if upkeep_col and (upkeep_col in df_local.columns):
        df_local[upkeep_col] = pd.to_numeric(df_local[upkeep_col], errors='coerce').fillna(0)
        df_local[upkeep_col] = (np.ceil(df_local[upkeep_col] / 0.25) * 0.25).round(2)
        df_local[upkeep_col] = df_local[upkeep_col].apply(lambda x: float(x) if x == int(x) else x)

    return df_local


def round_all_relevant_columns(df):
    """
    Round specified columns to appropriate decimal places.
    Ensures no trailing zeros in upkeep columns if the final value is an integer.
    """
    # Define rounding specifications for columns
    rounding_specs = {
        'health': 0,  # Round to integer
        'damage': 0,  # Round to integer
        'morale_damage': 2,  # Two decimals
        'collateral_damage': 2,  # Two decimals
        'war_exhaustion': 3  # Three decimals
    }

    # Dynamically identify upkeep columns and set rounding to 2 decimals
    upkeep_cols = [col for col in df.columns if col.lower().startswith('upkeep_')]
    for col in upkeep_cols:
        rounding_specs[col] = 2

    # Apply rounding
    for col, decimals in rounding_specs.items():
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)
            df[col] = df[col].round(decimals)
            if decimals > 0:  # Remove trailing zeros if rounded value is integer
                df[col] = df[col].apply(lambda x: float(x) if x != int(x) else int(x))

    return df

# Example usage in the main pipeline:
df = round_all_relevant_columns(df)

# %% [markdown]
# ## Main Modeling & Prediction
# <a id="main-modeling--prediction"></a>

# %%
def main():
    """
    Pipeline:
      1. Load the full DataFrame of armies from get_sub_df.
      2. Identify & separate:
         a) Original armament armies (armament_df_original).
         b) Spawned armies (time=0, not defensive).
         c) Normal armies with no armaments (those that need new cost/upkeep).
         d) Defensive armies, etc.
      3. Fit PLS using only armament_df_original.
      4. Predict cost/upkeep for normal no-armament armies.
         - Apply cost & upkeep for them, dampen, round, etc.
      5. Predict upkeep only for spawned armies (split morale/no morale).
      6. Display the final separate tables.
    """

    
    # ----------------- Load & prep data ---------------------
    input_directory = r"C:\\Users\\Aaron\\Documents\\Paradox Interactive\\Stellaris\\mod\\(Merged)_3.14_Full\\common\\armies"
    df = get_sub_df(input_directory)

    # 1) armament_df_original: these start with cost/upkeep > 0
    armament_df = df[(df['cost_sr_armaments'] > 0) | (df['upkeep_sr_armaments'] > 0)].copy()

    defensive_df = df[df['defensive'] == "yes"].copy()

    cost_cols = [c for c in df.columns if c.startswith("cost_")]
    upkeep_cols = [c for c in df.columns if c.startswith("upkeep_")]

    zero_cost_upkeep_mask = (df[cost_cols + upkeep_cols].sum(axis=1) == 0)
    spawned_df = df[zero_cost_upkeep_mask & (df['defensive'] != "yes")].copy()

    remainder_df = df[
    ~df.index.isin(armament_df.index) & ~df.index.isin(defensive_df.index) & ~df.index.isin(spawned_df.index)].copy()

    
    # -------------- SPLIT NO-ARMAMENT BY MORALE --------------
    with_morale = remainder_df[remainder_df['morale'] > 0].copy()
    no_morale = remainder_df[remainder_df['morale'] <= 0].copy()

    # -------------- Fit PLS on armament_df_original --------------
    armament_with_morale = armament_df[armament_df['morale'] > 0].copy()
    armament_no_morale = armament_df[armament_df['morale'] <= 0].copy()

    metrics_with_morale = ['time', 'damage', 'health', 'morale_damage', 'collateral_damage', 'war_exhaustion', 'morale']
    metrics_no_morale = ['time', 'damage', 'health', 'morale_damage', 'collateral_damage', 'war_exhaustion']

    # Convert numeric in the armament subsets
    for m in metrics_with_morale:
        armament_with_morale[m] = pd.to_numeric(armament_with_morale[m], errors='coerce').fillna(0)
    for m in metrics_no_morale:
        armament_no_morale[m] = pd.to_numeric(armament_no_morale[m], errors='coerce').fillna(0)

    # Fit cost models
    cost_model_with, scaler_cost_with = fit_pls_model(armament_with_morale, metrics_with_morale, 'cost_sr_armaments')
    cost_model_no, scaler_cost_no = fit_pls_model(armament_no_morale, metrics_no_morale, 'cost_sr_armaments')

    # Fit upkeep models
    upkeep_model_with, scaler_upkeep_with = fit_pls_model(armament_with_morale, metrics_with_morale, 'upkeep_sr_armaments')
    upkeep_model_no, scaler_upkeep_no = fit_pls_model(armament_no_morale, metrics_no_morale, 'upkeep_sr_armaments')


    
    #  5) Predict cost & upkeep for normal_no_armament armies
    for m in metrics_with_morale:
        with_morale[m] = pd.to_numeric(with_morale[m], errors='coerce').fillna(0)
    for m in metrics_no_morale:
        no_morale[m] = pd.to_numeric(no_morale[m], errors='coerce').fillna(0)

    # WITH morale
    with_morale['cost_sr_armaments'] = predict_pls(
        with_morale, metrics_with_morale, cost_model_with, scaler_cost_with
    ).round(0)
    with_morale['upkeep_sr_armaments'] = predict_pls(
        with_morale, metrics_with_morale, upkeep_model_with, scaler_upkeep_with
    ).round(1)
    with_morale = apply_dampening(with_morale, armament_with_morale, dampening_config)
    with_morale = round_cost_upkeep(with_morale,
                                    cost_col='cost_sr_armaments',
                                    upkeep_col='upkeep_sr_armaments')

    # NO morale
    no_morale['cost_sr_armaments'] = predict_pls(
        no_morale, metrics_no_morale, cost_model_no, scaler_cost_no
    ).round(0)
    no_morale['upkeep_sr_armaments'] = predict_pls(
        no_morale, metrics_no_morale, upkeep_model_no, scaler_upkeep_no
    ).round(1)
    no_morale = apply_dampening(no_morale, armament_no_morale, dampening_config)
    no_morale = round_cost_upkeep(no_morale, cost_col='cost_sr_armaments', upkeep_col='upkeep_sr_armaments')

    
    # -------------------------------------------------------
    #  9) Display
    # -------------------------------------------------------

    # Apply rounding to all tables before display
    with_morale = round_all_relevant_columns(with_morale)
    no_morale = round_all_relevant_columns(no_morale)
    spawned_df = round_all_relevant_columns(spawned_df)
    defensive_df = round_all_relevant_columns(defensive_df)
    armament_df = round_all_relevant_columns(armament_df)

    # Define colors for each variation
    colors = {
        "with_morale_cost": "blue",
        "with_morale_upkeep": "green",
        "no_morale_cost": "red",
        "no_morale_upkeep": "orange",
    }
    
    # Specify chart size
    chart_size1 = (14, 10)
    chart_size2 = (14, 8)
    
    # Scatter plots for WITH Morale armies
    print("WITH Morale:")
    scatter_charts(with_morale, metrics_with_morale, 'cost_sr_armaments', "Armament Cost", colors["with_morale_cost"], figsize=chart_size1)
    scatter_charts(with_morale, metrics_with_morale, 'upkeep_sr_armaments', "Upkeep", colors["with_morale_upkeep"], figsize=chart_size1)
    
    # Scatter plots for NO Morale armies
    print("NO Morale:")
    scatter_charts(no_morale, metrics_no_morale, 'cost_sr_armaments', "Armament Cost", colors["no_morale_cost"], figsize=chart_size2)
    scatter_charts(no_morale, metrics_no_morale, 'upkeep_sr_armaments', "Armament Upkeep", colors["no_morale_upkeep"], figsize=chart_size2)

    print(f"\n=== Original Armament Armies (unchanged) === (count: {len(armament_df)})")
    display_scrollable_df(armament_df)

    print(f"\n=== Spawned Armies=== (count: {len(spawned_df)})")
    display_scrollable_df(spawned_df)

    print(f"\n=== Normal No-Armament WITH Morale === (count: {len(with_morale)})")
    display_scrollable_df(with_morale)

    print(f"\n=== Normal No-Armament NO Morale === (count: {len(no_morale)})")
    display_scrollable_df(no_morale)

    print(f"\n=== Defensive Armies === (count: {len(defensive_df)})")
    display_scrollable_df(defensive_df)

# %% [markdown]
# ## Graphics and Tables

# %%
if __name__ == "__main__":
    main()
# Out:
# WITH Morale:
# NO Morale:
# === Original Armament Armies (unchanged) === (count: 107)
#     <div style='max-height:800px; max-width:1400px;
#                 overflow:auto; border:1px solid #ccc;'>
#         <style type="text/css">
# #T_d006c_row0_col8, #T_d006c_row0_col11, #T_d006c_row1_col8, #T_d006c_row1_col11, #T_d006c_row2_col8, #T_d006c_row2_col11, #T_d006c_row2_col12, #T_d006c_row3_col8, #T_d006c_row3_col11, #T_d006c_row4_col8, #T_d006c_row4_col12, #T_d006c_row5_col8, #T_d006c_row5_col11, #T_d006c_row5_col12, #T_d006c_row6_col8, #T_d006c_row6_col11, #T_d006c_row6_col18, #T_d006c_row7_col8, #T_d006c_row7_col11, #T_d006c_row8_col8, #T_d006c_row8_col11, #T_d006c_row9_col8, #T_d006c_row9_col11, #T_d006c_row10_col8, #T_d006c_row10_col11, #T_d006c_row11_col8, #T_d006c_row11_col11, #T_d006c_row12_col8, #T_d006c_row12_col11, #T_d006c_row13_col8, #T_d006c_row13_col11, #T_d006c_row14_col8, #T_d006c_row14_col11, #T_d006c_row15_col8, #T_d006c_row15_col11, #T_d006c_row16_col8, #T_d006c_row16_col11, #T_d006c_row17_col8, #T_d006c_row17_col11, #T_d006c_row18_col8, #T_d006c_row18_col12, #T_d006c_row19_col8, #T_d006c_row19_col11, #T_d006c_row20_col8, #T_d006c_row20_col11, #T_d006c_row21_col8, #T_d006c_row21_col11, #T_d006c_row22_col8, #T_d006c_row22_col11, #T_d006c_row22_col12, #T_d006c_row23_col8, #T_d006c_row23_col11, #T_d006c_row24_col8, #T_d006c_row24_col12, #T_d006c_row25_col8, #T_d006c_row25_col12, #T_d006c_row26_col8, #T_d006c_row26_col11, #T_d006c_row27_col8, #T_d006c_row27_col11, #T_d006c_row28_col11, #T_d006c_row29_col8, #T_d006c_row29_col11, #T_d006c_row30_col8, #T_d006c_row30_col11, #T_d006c_row31_col8, #T_d006c_row31_col11, #T_d006c_row31_col18, #T_d006c_row32_col8, #T_d006c_row32_col11, #T_d006c_row33_col8, #T_d006c_row33_col11, #T_d006c_row34_col8, #T_d006c_row34_col11, #T_d006c_row35_col8, #T_d006c_row35_col11, #T_d006c_row36_col8, #T_d006c_row36_col13, #T_d006c_row37_col8, #T_d006c_row37_col11, #T_d006c_row38_col8, #T_d006c_row38_col11, #T_d006c_row39_col8, #T_d006c_row39_col11, #T_d006c_row40_col8, #T_d006c_row40_col11, #T_d006c_row41_col8, #T_d006c_row41_col12, #T_d006c_row41_col17, #T_d006c_row41_col21, #T_d006c_row41_col23, #T_d006c_row42_col8, #T_d006c_row42_col11, #T_d006c_row42_col17, #T_d006c_row43_col8, #T_d006c_row43_col11, #T_d006c_row43_col17, #T_d006c_row44_col8, #T_d006c_row44_col11, #T_d006c_row45_col8, #T_d006c_row45_col11, #T_d006c_row46_col8, #T_d006c_row46_col11, #T_d006c_row47_col8, #T_d006c_row47_col11, #T_d006c_row48_col8, #T_d006c_row48_col11, #T_d006c_row49_col8, #T_d006c_row49_col11, #T_d006c_row50_col8, #T_d006c_row50_col11, #T_d006c_row51_col8, #T_d006c_row51_col11, #T_d006c_row52_col8, #T_d006c_row52_col11, #T_d006c_row53_col8, #T_d006c_row53_col11, #T_d006c_row54_col8, #T_d006c_row54_col11, #T_d006c_row55_col8, #T_d006c_row55_col11, #T_d006c_row56_col8, #T_d006c_row56_col11, #T_d006c_row57_col8, #T_d006c_row57_col11, #T_d006c_row58_col8, #T_d006c_row58_col11, #T_d006c_row59_col8, #T_d006c_row59_col11, #T_d006c_row60_col8, #T_d006c_row60_col11, #T_d006c_row61_col8, #T_d006c_row61_col11, #T_d006c_row62_col8, #T_d006c_row62_col11, #T_d006c_row63_col8, #T_d006c_row63_col11, #T_d006c_row64_col8, #T_d006c_row64_col11, #T_d006c_row65_col8, #T_d006c_row65_col11, #T_d006c_row66_col8, #T_d006c_row66_col11, #T_d006c_row67_col8, #T_d006c_row67_col11, #T_d006c_row68_col8, #T_d006c_row68_col14, #T_d006c_row69_col8, #T_d006c_row69_col11, #T_d006c_row70_col8, #T_d006c_row70_col14, #T_d006c_row71_col8, #T_d006c_row71_col11, #T_d006c_row72_col8, #T_d006c_row72_col11, #T_d006c_row73_col8, #T_d006c_row74_col8, #T_d006c_row74_col11, #T_d006c_row75_col8, #T_d006c_row75_col22, #T_d006c_row76_col8, #T_d006c_row76_col11, #T_d006c_row76_col14, #T_d006c_row77_col8, #T_d006c_row77_col11, #T_d006c_row77_col14, #T_d006c_row78_col8, #T_d006c_row78_col11, #T_d006c_row78_col14, #T_d006c_row79_col8, #T_d006c_row79_col11, #T_d006c_row79_col14, #T_d006c_row80_col8, #T_d006c_row80_col11, #T_d006c_row80_col14, #T_d006c_row81_col8, #T_d006c_row81_col12, #T_d006c_row82_col8, #T_d006c_row82_col11, #T_d006c_row82_col14, #T_d006c_row83_col13, #T_d006c_row84_col13, #T_d006c_row85_col8, #T_d006c_row85_col13, #T_d006c_row86_col8, #T_d006c_row86_col13, #T_d006c_row87_ ...
#   background-color: #fffbcc;
#   background-color: #fffbcc;
# }
# #T_d006c_row0_col9, #T_d006c_row0_col10, #T_d006c_row1_col9, #T_d006c_row1_col10, #T_d006c_row2_col9, #T_d006c_row2_col10, #T_d006c_row3_col9, #T_d006c_row3_col10, #T_d006c_row4_col9, #T_d006c_row4_col10, #T_d006c_row5_col9, #T_d006c_row5_col10, #T_d006c_row6_col9, #T_d006c_row6_col10, #T_d006c_row6_col20, #T_d006c_row7_col9, #T_d006c_row7_col10, #T_d006c_row8_col9, #T_d006c_row8_col10, #T_d006c_row9_col9, #T_d006c_row9_col10, #T_d006c_row10_col9, #T_d006c_row10_col10, #T_d006c_row11_col9, #T_d006c_row11_col10, #T_d006c_row12_col9, #T_d006c_row12_col10, #T_d006c_row13_col9, #T_d006c_row13_col10, #T_d006c_row14_col9, #T_d006c_row14_col10, #T_d006c_row15_col9, #T_d006c_row15_col10, #T_d006c_row16_col9, #T_d006c_row16_col10, #T_d006c_row17_col9, #T_d006c_row17_col10, #T_d006c_row18_col9, #T_d006c_row18_col10, #T_d006c_row19_col9, #T_d006c_row19_col10, #T_d006c_row20_col9, #T_d006c_row20_col10, #T_d006c_row21_col9, #T_d006c_row21_col10, #T_d006c_row22_col9, #T_d006c_row22_col10, #T_d006c_row23_col9, #T_d006c_row23_col10, #T_d006c_row24_col9, #T_d006c_row24_col10, #T_d006c_row25_col9, #T_d006c_row25_col10, #T_d006c_row26_col9, #T_d006c_row26_col10, #T_d006c_row27_col9, #T_d006c_row27_col10, #T_d006c_row28_col9, #T_d006c_row28_col10, #T_d006c_row29_col9, #T_d006c_row29_col10, #T_d006c_row30_col9, #T_d006c_row30_col10, #T_d006c_row31_col9, #T_d006c_row31_col10, #T_d006c_row31_col20, #T_d006c_row32_col9, #T_d006c_row32_col10, #T_d006c_row33_col9, #T_d006c_row33_col10, #T_d006c_row34_col9, #T_d006c_row34_col10, #T_d006c_row35_col9, #T_d006c_row35_col10, #T_d006c_row36_col9, #T_d006c_row36_col10, #T_d006c_row37_col9, #T_d006c_row37_col10, #T_d006c_row38_col9, #T_d006c_row38_col10, #T_d006c_row39_col9, #T_d006c_row39_col10, #T_d006c_row40_col9, #T_d006c_row40_col10, #T_d006c_row41_col9, #T_d006c_row41_col10, #T_d006c_row42_col9, #T_d006c_row42_col10, #T_d006c_row42_col19, #T_d006c_row43_col9, #T_d006c_row43_col10, #T_d006c_row43_col19, #T_d006c_row44_col9, #T_d006c_row44_col10, #T_d006c_row45_col9, #T_d006c_row45_col10, #T_d006c_row46_col9, #T_d006c_row46_col10, #T_d006c_row47_col9, #T_d006c_row47_col10, #T_d006c_row48_col9, #T_d006c_row48_col10, #T_d006c_row49_col9, #T_d006c_row49_col10, #T_d006c_row50_col9, #T_d006c_row50_col10, #T_d006c_row51_col9, #T_d006c_row51_col10, #T_d006c_row52_col9, #T_d006c_row52_col10, #T_d006c_row53_col9, #T_d006c_row53_col10, #T_d006c_row54_col9, #T_d006c_row54_col10, #T_d006c_row55_col9, #T_d006c_row55_col10, #T_d006c_row56_col9, #T_d006c_row56_col10, #T_d006c_row57_col9, #T_d006c_row57_col10, #T_d006c_row58_col9, #T_d006c_row58_col10, #T_d006c_row59_col9, #T_d006c_row59_col10, #T_d006c_row60_col9, #T_d006c_row60_col10, #T_d006c_row61_col9, #T_d006c_row61_col10, #T_d006c_row62_col9, #T_d006c_row62_col10, #T_d006c_row63_col9, #T_d006c_row63_col10, #T_d006c_row64_col9, #T_d006c_row64_col10, #T_d006c_row65_col9, #T_d006c_
# === Spawned Armies=== (count: 36)
#     <div style='max-height:800px; max-width:1400px;
#                 overflow:auto; border:1px solid #ccc;'>
#         <style type="text/css">
# </style>
# <table id="T_9b589">
#   <thead>
#     <tr>
#       <th id="T_9b589_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9b589_level0_col1" class="col_heading level0 col1" >time</th>
#       <th id="T_9b589_level0_col2" class="col_heading level0 col2" >health</th>
#       <th id="T_9b589_level0_col3" class="col_heading level0 col3" >damage</th>
#       <th id="T_9b589_level0_col4" class="col_heading level0 col4" >morale</th>
#       <th id="T_9b589_level0_col5" class="col_heading level0 col5" >morale_damage</th>
#       <th id="T_9b589_level0_col6" class="col_heading level0 col6" >collateral_damage</th>
#       <th id="T_9b589_level0_col7" class="col_heading level0 col7" >war_exhaustion</th>
#       <th id="T_9b589_level0_col8" class="col_heading level0 col8" >cost_sr_armaments</th>
#       <th id="T_9b589_level0_col9" class="col_heading level0 col9" >upkeep_sr_armaments</th>
#       <th id="T_9b589_level0_col10" class="col_heading level0 col10" >defensive</th>
#       <th id="T_9b589_level0_col11" class="col_heading level0 col11" >cost_acot_sr_dark_energy</th>
#       <th id="T_9b589_level0_col12" class="col_heading level0 col12" >cost_acot_sr_light_matter</th>
#       <th id="T_9b589_level0_col13" class="col_heading level0 col13" >cost_acot_sr_stellarite</th>
#       <th id="T_9b589_level0_col14" class="col_heading level0 col14" >cost_alloys</th>
#       <th id="T_9b589_level0_col15" class="col_heading level0 col15" >cost_astral_threads</th>
#       <th id="T_9b589_level0_col16" class="col_heading level0 col16" >cost_energy</th>
#       <th id="T_9b589_level0_col17" class="col_heading level0 col17" >cost_exotic_gases</th>
#       <th id="T_9b589_level0_col18" class="col_heading level0 col18" >cost_food</th>
#       <th id="T_9b589_level0_col19" class="col_heading level0 col19" >cost_influence</th>
#       <th id="T_9b589_level0_col20" class="col_heading level0 col20" >cost_minerals</th>
#       <th id="T_9b589_level0_col21" class="col_heading level0 col21" >cost_minor_artifacts</th>
#       <th id="T_9b589_level0_col22" class="col_heading level0 col22" >cost_nanites</th>
#       <th id="T_9b589_level0_col23" class="col_heading level0 col23" >cost_rare_crystals</th>
#       <th id="T_9b589_level0_col24" class="col_heading level0 col24" >cost_sr_dark_matter</th>
#       <th id="T_9b589_level0_col25" class="col_heading level0 col25" >cost_sr_zro</th>
#       <th id="T_9b589_level0_col26" class="col_heading level0 col26" >cost_unity</th>
#       <th id="T_9b589_level0_col27" class="col_heading level0 col27" >cost_volatile_motes</th>
#       <th id="T_9b589_level0_col28" class="col_heading level0 col28" >upkeep_acot_sr_stellarite</th>
#       <th id="T_9b589_level0_col29" class="col_heading level0 col29" >upkeep_alloys</th>
#       <th id="T_9b589_level0_col30" class="col_heading level0 col30" >upkeep_energy</th>
#       <th id="T_9b589_level0_col31" class="col_heading level0 col31" >upkeep_food</th>
#       <th id="T_9b589_level0_col32" class="col_heading level0 col32" >upkeep_influence</th>
#       <th id="T_9b589_level0_col33" class="col_heading level0 col33" >upkeep_minerals</th>
#       <th id="T_9b589_level0_col34" class="col_heading level0 col34" >upkeep_minor_artifacts</th>
#       <th id="T_9b589_level0_col35" class="col_heading level0 col35" >upkeep_rare_crystals</th>
#       <th id="T_9b589_level0_col36" class="col_heading level0 col36" >upkeep_sr_zro</th>
#       <th id="T_9b589_level0_col37" class="col_heading level0 col37" >upkeep_unity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9
#       <th id="T_5d49a_level0_col12" class="col_heading level0 col12" >cost_minerals</th>
#       <th id="T_5d49a_level0_col13" class="col_heading level0 col13" >upkeep_alloys</th>
#       <th id="T_5d49a_level0_col14" class="col_heading level0 col14" >cost_energy</th>
#       <th id="T_5d49a_level0_col15" class="col_heading level0 col15" >cost_food</th>
#       <th id="T_5d49a_level0_col16" class="col_heading level0 col16" >upkeep_food</th>
#       <th id="T_5d49a_level0_col17" class="col_heading level0 col17" >cost_acot_sr_dark_energy</th>
#       <th id="T_5d49a_level0_col18" class="col_heading level0 col18" >cost_acot_sr_light_matter</th>
#       <th id="T_5d49a_level0_col19" class="col_heading level0 col19" >cost_acot_sr_stellarite</th>
#       <th id="T_5d49a_level0_col20" class="col_heading level0 col20" >cost_alloys</th>
#       <th id="T_5d49a_level0_col21" class="col_heading level0 col21" >cost_astral_threads</th>
#       <th id="T_5d49a_level0_col22" class="col_heading level0 col22" >cost_exotic_gases</th>
#       <th id="T_5d49a_level0_col23" class="col_heading level0 col23" >cost_influence</th>
#       <th id="T_5d49a_level0_col24" class="col_heading level0 col24" >cost_minor_artifacts</th>
#       <th id="T_5d49a_level0_col25" class="col_heading level0 col25" >cost_nanites</th>
#       <th id="T_5d49a_level0_col26" class="col_heading level0 col26" >cost_rare_crystals</th>
#       <th id="T_5d49a_level0_col27" class="col_heading level0 col27" >cost_sr_dark_matter</th>
#       <th id="T_5d49a_level0_col28" class="col_heading level0 col28" >cost_sr_zro</th>
#       <th id="T_5d49a_level0_col29" class="col_heading level0 col29" >cost_unity</th>
#       <th id="T_5d49a_level0_col30" class="col_heading level0 col30" >cost_volatile_motes</th>
#       <th id="T_5d49a_level0_col31" class="col_heading level0 col31" >upkeep_acot_sr_stellarite</th>
#       <th id="T_5d49a_level0_col32" class="col_heading level0 col32" >upkeep_influence</th>
#       <th id="T_5d49a_level0_col33" class="col_heading level0 col33" >upkeep_minerals</th>
#       <th id="T_5d49a_level0_col34" class="col_heading level0 col34" >upkeep_minor_artifacts</th>
#       <th id="T_5d49a_level0_col35" class="col_heading level0 col35" >upkeep_rare_crystals</th>
#       <th id="T_5d49a_level0_col36" class="col_heading level0 col36" >upkeep_sr_zro</th>
#       <th id="T_5d49a_level0_col37" class="col_heading level0 col37" >upkeep_unity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d49a_row0_col0" class="data row0 col0" >hoplite_army</td>
#       <td id="T_5d49a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5d49a_row0_col2" class="data row0 col2" >0.750000</td>
#       <td id="T_5d49a_row0_col3" class="data row0 col3" >0.750000</td>
#       <td id="T_5d49a_row0_col4" class="data row0 col4" >2.00</td>
#       <td id="T_5d49a_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_5d49a_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_5d49a_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_5d49a_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_5d49a_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_5d49a_row0_col10" class="data row0 col10" >yes</td>
#       <td id="T_5d49a_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_5d49a_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_5d49a_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_5d49a_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_5d49a_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_5d49a_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_5d49a_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_5d49a_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_5d49a_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_5d49a_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_5d49a_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_5d49a_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_5d49a_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_5d49a_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_5d49a_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_5d49a_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_5d49a_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_5d49a_row0_col28" class="data row0 col28" >0</td>
#       <td id="T_5d49a_row0_col29" class="data row0 col29" >0</td>
#       <td id="T_5d49a_row0_col30" class="data row0 col30" >0</td>
#       <td id="T_5d49a_row0_col31" class="data row0 col31" >0.000000</td>
#       <td id="T_5d49a_row0_c
